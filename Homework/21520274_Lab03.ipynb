# %%
# !pip install python_speech_features
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5872 sha256=bbea87e2ccbd381e842bc4e56b6dc708d9e9a2e2f2b341b502d8754962cab1bf
#   Stored in directory: /root/.cache/pip/wheels/5a/9e/68/30bad9462b3926c29e315df16b562216d12bdc215f4d240294
# Successfully built python_speech_features
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from python_speech_features import mfcc, logfbank

# %%
#download a file .wav in my drive
import gdown

# !gdown https://drive.google.com/uc?id=1uAptITRlDgs-rgziCVfjzEF7YxMh5wdS
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uAptITRlDgs-rgziCVfjzEF7YxMh5wdS
# To: /content/CaiLuong.001.wav
# 100% 1.32M/1.32M [00:00<00:00, 12.7MB/s]

# %%
#Đọc tệp âm thanh lưu trữ
path = '/content/CaiLuong.001.wav'
frequency_sampling, audio_signal = wavfile.read(path)
# Out:
# <ipython-input-6-100c327f374a>:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   frequency_sampling, audio_signal = wavfile.read(path)

# %%
# Lưu ý đang lấy 15000 mẫu đầu tiên để phân tích.
audio_signal = audio_signal[:15000]

# %%
# Sử dụng các kỹ thuật MFCC và thực hiện lệnh sau để trích xuất các tính năng của MFCC
features_mfcc = mfcc(audio_signal, frequency_sampling)
# Out:
# WARNING:root:frame length (551) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.

# %%
# in các tham số MFCC, như được hiển thị
print('\nMFCC:\nNumber of windows =', features_mfcc.shape[0])
print('Length of each feature =', features_mfcc.shape[1])
# Out:
# MFCC:
# Number of windows = 67
# Length of each feature = 13

# %%
# vẽ đồ thị và trực quan hóa các tính năng của MFCC bằng cách sử dụng các lệnh dưới đây
features_mfcc = features_mfcc.T
plt.matshow(features_mfcc)
plt.title('MFCC')
plt.show()

# %%
# Trích xuất các tính năng bộ lọc
filterbank_features = logfbank(audio_signal, frequency_sampling)
# Out:
# WARNING:root:frame length (551) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.

# %%
# in các tham số bộ lọc.
print('\nFilter bank:\nNumber of windows =', filterbank_features.shape[0])
print('Length of each feature =', filterbank_features.shape[1])
# Out:
# Filter bank:
# Number of windows = 67
# Length of each feature = 26

# %%
# vẽ sơ đồ và trực quan hóa các tính năng của bộ lọc.
filterbank_features = filterbank_features.T
plt.matshow(filterbank_features)
plt.title('Filter bank')
plt.show()
